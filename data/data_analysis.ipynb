# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
root_path = '/content/drive/MyDrive/Projects/StartupValuation/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data Preparation

# %%
startup_df = pd.read_csv(root_path + 'dataset.csv')

# %% [markdown]
# ### Data Inspection and Cleaning

# %%
# Check the first few rows
startup_df.head()

# Get information about the data
startup_df.info()

# Describe the data
startup_df.describe()

# Check for missing values
startup_df.isnull().sum()

# Convert dates and handle missing values
startup_df['founded_at'] = pd.to_datetime(startup_df['founded_at'], errors='coerce')
startup_df.fillna(0, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196498 entries, 0 to 196497
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           196498 non-null  object
#  1   category_code                123132 non-null  object
#  2   status                       196498 non-null  object
#  3   founded_at                   91181 non-null   object
#  4   logo_width                   196498 non-null  int64
#  5   logo_height                  196498 non-null  int64
#  6   country_code                 87935 non-null   object
#  7   investment_rounds            196498 non-null  int64
#  8   invested_companies           196498 non-null  int64
#  9   funding_rounds               196498 non-null  int64
#  10  funding_total_usd            196498 non-null  float64
#  11  milestones                   196498 non-null  int64
#  12  relationships                196498 non-null  int64
#  13  object_id                    1238 non-null    object
#  14  angel                        31703 non-null   float64
#  15  crowdfunding                 31703 non-null   float64
#  16  other                        31703 non-null   float64
#  17  post_ipo                     31703 non-null   float64
#  18  private_equity               31703 non-null   float64
#  19  series_a                     31703 non-null   float64
#  20  series_b                     31703 non-null   float64
#  21  series_c                     31703 non-null   float64
#  22  venture                      31703 non-null   float64
#  23  acquiring_object_id          4847 non-null    object
#  24  num_acquisizioni_effettuate  196498 non-null  float64
#  25  acquired_object_id           9393 non-null    object
#  26  have_been_acquired           196498 non-null  float64
#  27  funded_object_id_x           17851 non-null   object
#  28  fin_org_financed             196498 non-null  float64
#  29  funded_object_id_y           4421 non-null    object
#  30  person_financed              196498 non-null  float64
#  31  funded_object_id             4795 non-null    object
#  32  startup_financed             196498 non-null  float64
#  33  parent_id                    11749 non-null   object
#  34  num_prodotti                 196498 non-null  float64
# dtypes: float64(16), int64(7), object(12)
# memory usage: 52.5+ MB

# %% [markdown]
# ## Data Exploration and Analysis

# %% [markdown]
# ### Data Description

# %%
print(startup_df['status'].value_counts())
print(startup_df.groupby('country_code').size())
# Out:
# status
# operating    183387
# acquired       9393
# closed         2584
# ipo            1134
# Name: count, dtype: int64
# country_code
# 0      108563
# AFG         8
# AGO         2
# AIA         1
# ALB        10
#         ...
# VNM        67
# YEM         2
# ZAF       277
# ZMB         2
# ZWE         4
# Length: 174, dtype: int64

# %% [markdown]
# ### Data Visualization

# %%
# Univariate Analysis
plt.figure(figsize=(10, 6))
startup_df['status'].value_counts().plot(kind='bar')
plt.title('Distribution of Startup Status')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()

# %%
# Bivariate Analysis
plt.figure(figsize=(10, 6))
sns.boxplot(x='status', y='funding_rounds', data=startup_df)
plt.title('Funding Rounds by Startup Status')
plt.xlabel('Status')
plt.ylabel('Funding Rounds')
plt.show()

# %%
# Multivariate Analysis
sns.pairplot(startup_df[['funding_rounds', 'investment_rounds', 'num_prodotti', 'status']], hue='status')
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(12, 8))
correlation_matrix = startup_df.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
